# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("players_20.csv")
data.head()
data = data.fillna(0)
data = data[data.club != 'Portugal']

# %%
position = "LWB"
position1 = "LB"
position2 = "RB"
position3 = "RWB"
position4 = "LCB"
position5 = "CB"
position6 = "RCB"
position7 = "LDM"
position8 = "CDM"
position9 = "RDM"
defender = data[(data.player_positions.str.contains(position)) | 
               (data.player_positions.str.contains(position1)) | 
               (data.player_positions.str.contains(position2)) | 
               (data.player_positions.str.contains(position3)) | 
               (data.player_positions.str.contains(position4)) | 
               (data.player_positions.str.contains(position5)) | 
               (data.player_positions.str.contains(position6)) |
               (data.player_positions.str.contains(position7)) |
               (data.player_positions.str.contains(position8)) |
               (data.player_positions.str.contains(position9))]

#midfielders
position = "LW"
position1 = "RW"
position2 = "LAM"
position3 = "CAM"
position4 = "RAM"
position5 = "LM"
position6 = "LCM"
position7 = "CM"
position8 = "RCM"
position9 = "RM"
midfielder = data[(data.player_positions.str.contains(position)) | 
               (data.player_positions.str.contains(position1)) | 
               (data.player_positions.str.contains(position2)) | 
               (data.player_positions.str.contains(position3)) | 
               (data.player_positions.str.contains(position4)) | 
               (data.player_positions.str.contains(position5)) | 
               (data.player_positions.str.contains(position6)) |
               (data.player_positions.str.contains(position7)) |
               (data.player_positions.str.contains(position8)) |
               (data.player_positions.str.contains(position9))]
position = "LS"
position1 = "ST"
position2 = "RS"
position3 = "LF"
position4 = "CF"
position5 = "RF"

#forward
forward = data[(data.player_positions.str.contains(position)) | 
               (data.player_positions.str.contains(position1)) | 
               (data.player_positions.str.contains(position2)) | 
               (data.player_positions.str.contains(position3)) | 
               (data.player_positions.str.contains(position4)) | 
               (data.player_positions.str.contains(position5))]

#goalkeepers
position = "GK"
goalkeeper = data[data.player_positions.str.contains(position)]

# %%
defender_score = defender.groupby('club').mean()[['potential','overall','pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic',
                     'defending_marking','defending_standing_tackle','defending_sliding_tackle',
                     'movement_acceleration','movement_sprint_speed','movement_agility', 'movement_reactions','movement_balance','power_shot_power','power_jumping',
               'power_stamina','power_strength','power_long_shots','mentality_aggression', 'mentality_interceptions','mentality_positioning',
               'mentality_vision','mentality_penalties','mentality_composure','skill_dribbling', 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
                                                 'lwb','lb','rb','rwb','lcb','cb','rcb','ldm','cdm','rdm']]
d_score = defender_score.mean(axis = 1).sort_values(ascending=False).reset_index(name ='defender_score')
d_score
# Out:
#                   club  defender_score
# 0    FC Bayern München       74.235931
# 1             Juventus       71.801587
# 2          Real Madrid       71.687075
# 3              Uruguay       71.247253
# 4              Chelsea       70.926871
# ..                 ...             ...
# 687      Śląsk Wrocław       51.190476
# 688         Finn Harps       50.954762
# 689      Leyton Orient       50.809524
# 690   Bolton Wanderers       50.510823
# 691            UCD AFC       48.654762
#
# [692 rows x 2 columns]

# %%
midfielder_score = midfielder.groupby('club').mean()[['pace', 'shooting', 'passing', 'potential','overall',
                                                      'dribbling', 'defending', 'physic', 
                                                      'attacking_crossing', 'attacking_finishing', 
                                                      'attacking_heading_accuracy', 'attacking_short_passing', 'attacking_volleys', 'skill_dribbling', 
                                                      'skill_curve', 'skill_fk_accuracy', 'skill_long_passing', 
                                                      'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed', 'movement_agility', 
                                                      'movement_reactions', 'movement_balance', 'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots', 'mentality_aggression', 'mentality_interceptions', 'mentality_positioning', 'mentality_vision', 'mentality_penalties', 'mentality_composure', 'lw', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm']
]
m_score = midfielder_score.mean(axis = 1).reset_index(name ='midfielder_score')
m_score
# mf.sort_values(ascending=False)
# Out:
#                       club  midfielder_score
# 0      SSV Jahn Regensburg         60.189394
# 1    1. FC Heidenheim 1846         62.257576
# 2     1. FC Kaiserslautern         59.186080
# 3               1. FC Köln         64.636364
# 4          1. FC Magdeburg         60.832645
# ..                     ...               ...
# 683    Yokohama F. Marinos         60.534091
# 684         Zagłębie Lubin         56.811364
# 685        Çaykur Rizespor         64.272727
# 686              Örebro SK         58.225379
# 687          Östersunds FK         56.954545
#
# [688 rows x 2 columns]

# %%
goalkeeper_score = goalkeeper.groupby('club').mean()[['pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic',
                                                      'gk_diving','gk_handling','gk_kicking','gk_reflexes','gk_speed',
                                                      'gk_positioning','movement_acceleration','movement_sprint_speed','movement_agility',
                                                      'movement_reactions','movement_balance','power_shot_power','power_jumping',
                                                      'power_stamina','power_strength','power_long_shots','mentality_aggression',
                                                      'mentality_interceptions','mentality_positioning','mentality_vision',
                                                      'mentality_penalties','mentality_composure','potential','overall']]
g_score = goalkeeper_score.mean(axis = 1).reset_index(name ='goalkeeper_score')
g_score
# Out:
#                       club  goalkeeper_score
# 0      SSV Jahn Regensburg         32.200000
# 1    1. FC Heidenheim 1846         33.591667
# 2     1. FC Kaiserslautern         31.011111
# 3               1. FC Köln         36.358333
# 4          1. FC Magdeburg         31.950000
# ..                     ...               ...
# 674    Yokohama F. Marinos         32.755556
# 675         Zagłębie Lubin         35.066667
# 676        Çaykur Rizespor         35.083333
# 677              Örebro SK         33.133333
# 678          Östersunds FK         33.744444
#
# [679 rows x 2 columns]

# %%
forward_score = forward.groupby('club').mean()[['attacking_crossing','attacking_finishing','attacking_heading_accuracy',
                     'attacking_short_passing','attacking_volleys','movement_acceleration',
                     'movement_sprint_speed','movement_agility',
               'movement_reactions','movement_balance','power_shot_power','power_jumping',
               'power_stamina','power_strength','power_long_shots','mentality_aggression',
               'mentality_interceptions','mentality_positioning',
               'mentality_vision','mentality_penalties','mentality_composure','pace', 'shooting', 
                     'passing', 'dribbling', 'defending', 'physic','ls','st','rs','lf','cf','rf','potential','overall']]
f_score = forward_score.mean(axis = 1).reset_index(name ='forward_score')
f_score
# Out:
#                       club  forward_score
# 0      SSV Jahn Regensburg      59.348571
# 1    1. FC Heidenheim 1846      59.050612
# 2     1. FC Kaiserslautern      60.996190
# 3               1. FC Köln      70.012857
# 4          1. FC Magdeburg      59.401633
# ..                     ...            ...
# 676    Yokohama F. Marinos      62.240635
# 677         Zagłębie Lubin      58.872381
# 678        Çaykur Rizespor      67.405714
# 679              Örebro SK      58.177143
# 680          Östersunds FK      56.484286
#
# [681 rows x 2 columns]

# %%
final_score = g_score.merge(f_score,on='club').merge(m_score,on='club').merge(d_score,on='club')
final_score['final_score_20'] = final_score.mean(axis = 1)
final_score = final_score.sort_values(ascending=False, by='final_score_20')
final_score
# Out:
#                   club  goalkeeper_score  forward_score  midfielder_score  \
# 342           Juventus         43.091667      74.790000         73.892344
# 218       FC Barcelona         42.788889      77.772857         71.104545
# 491        Real Madrid         41.555556      74.780408         72.507102
# 220  FC Bayern München         40.066667      70.757143         74.835664
# 393  Manchester United         45.088889      73.078095         71.274148
# ..                 ...               ...            ...               ...
# 105               Bury         29.250000      54.971429         53.972028
# 268         Finn Harps         32.350000      55.155714         51.492898
# 169    Crewe Alexandra         32.416667      51.929524         52.724026
# 655       Waterford FC         27.916667      49.539048         55.609091
# 615            UCD AFC         30.344444      50.948571         51.061688
#
#      defender_score  final_score_20
# 342       71.801587       65.893900
# 218       70.384921       65.512803
# 491       71.687075       65.132535
# 220       74.235931       64.973851
# 393       69.664160       64.776323
# ..              ...             ...
# 105       52.375000       47.642114
# 268       50.954762       47.488343
# 169       51.281385       47.087900
# 655       51.628571       46.173344
# 615       48.654762       45.252367
#
# [674 rows x 6 columns]

# %%
final_score = final_score.iloc[:10,:]
plt.bar(final_score.club, final_score.final_score_20, width=0.5, color='green')
plt.xticks(rotation=80);
plt.ylim(0, 70);
plt.xlabel('Top 10 Teams in 2020')
plt.ylabel('Scores');

# %%
Score_report_20 = final_score.reset_index()
Score_report_20 = Score_report_20.head(50)
Score_report_20.to_csv('Score_report_15.csv')
Score_report_20.iloc[:, 1]
# Out:
# 0             Juventus
# 1         FC Barcelona
# 2          Real Madrid
# 3    FC Bayern München
# 4    Manchester United
# 5    Tottenham Hotspur
# 6              Uruguay
# 7      Manchester City
# 8    Borussia Dortmund
# 9                Milan
# Name: club, dtype: object
